# %%
import pandas as pd 
df=pd.read_csv("nba_playerstats_2013.csv")
df
# Out:
#       Rk             Player Pos  Age   Tm   G  GS    MP   FG  FGA  ...    FT%  \
# 0      1         Quincy Acy  PF   22  TOR  29   0   342   42   75  ...  0.816
# 1      2        Jeff Adrien  PF   26  CHA  52   5   713   72  168  ...  0.650
# 2      3      Arron Afflalo  SF   27  ORL  64  64  2307  397  905  ...  0.857
# 3      4       Josh Akognon  PG   26  DAL   3   0     9    2    4  ...    NaN
# 4      5       Cole Aldrich   C   24  TOT  45   0   388   44   80  ...  0.600
# ..   ...                ...  ..  ...  ...  ..  ..   ...  ...  ...  ...    ...
# 495  406  Sebastian Telfair  PG   27  TOT  59   2   980  112  309  ...  0.783
# 496  406  Sebastian Telfair  PG   27  PHO  46   2   795   94  247  ...  0.772
# 497  406  Sebastian Telfair  PG   27  TOR  13   0   185   18   62  ...  0.833
# 498  407     Garrett Temple  SG   26  WAS  51  36  1156  105  258  ...  0.703
# 499  408        Jason Terry  SG   35  BOS  79  24  2124  281  648  ...  0.870
#
# ...

# %%
df_clean= df.drop(["Age" , "Tm" , "GS" , "MP", "FG%", "3P", "3PA", "3P%", "2P" , "2PA", "2P%", "eFG%", "FT%",	"ORB","DRB", "PF", "Missed FG", "Player Efficiency" ], axis=1)
df_clean
# Out:
#       Rk             Player Pos   G   FG  FGA   FT  FTA  TRB  AST  STL  BLK  \
# 0      1         Quincy Acy  PF  29   42   75   31   38   77   11   13   15
# 1      2        Jeff Adrien  PF  52   72  168   65  100  196   36   18   27
# 2      3      Arron Afflalo  SF  64  397  905  191  223  239  206   40   11
# 3      4       Josh Akognon  PG   3    2    4    0    0    1    1    0    0
# 4      5       Cole Aldrich   C  45   44   80   12   20  120    9    5   23
# ..   ...                ...  ..  ..  ...  ...  ...  ...  ...  ...  ...  ...
# 495  406  Sebastian Telfair  PG  59  112  309   54   69   84  153   37   11
# 496  406  Sebastian Telfair  PG  46   94  247   44   57   68  114   28   10
# 497  406  Sebastian Telfair  PG  13   18   62   10   12   16   39    9    1
# 498  407     Garrett Temple  SG  51  105  258   26   37  123  115   50   17
# 499  408        Jason Terry  SG  79  281  648  114  131  159  198   66   11
#
#      TOV   PTS  Player Efficiency Rating
# ...

# %%
df["Player Efficiency Rating"]= (( df["PTS"] + df["TRB"]+ df["AST"] + df["STL"] + df["BLK"] ) - (df["TOV"]+((df["FGA"]-df["FG"]))+(df["FTA"]-df["FT"])))/df["G"]

# %%
 df_top10_EFF=df_clean.nlargest(10, 'Player Efficiency Rating')
df_top10_EFF
# Out:
#       Rk             Player Pos   G   FG   FGA   FT  FTA  TRB  AST  STL  BLK  \
# 255  213       LeBron James  PF  76  765  1354  403  535  610  551  129   67
# 148  120       Kevin Durant  SF  81  731  1433  679  750  640  374  116  105
# 78    64       Kobe Bryant*  SG  78  738  1595  525  626  433  469  106   25
# 208  170       James Harden  SG  78  585  1337  674  792  379  455  142   38
# 307  257          David Lee  PF  79  602  1160  255  320  886  279   67   22
# 146  118        Tim Duncan*   C  69  490   976  245  300  686  184   50  183
# 409  334         Chris Paul  PG  70  412   856  286  323  262  678  169   10
# 240  198         Al Horford   C  74  576  1060  134  208  757  240   78   78
# 22    16    Carmelo Anthony  PF  67  669  1489  425  512  460  171   52   32
# 7      6  LaMarcus Aldridge  PF  74  638  1318  282  348  670  192   62   91
#
#      TOV   PTS  Player Efficiency Rating
# 255  226  2036                 32.184211
# ...

# %%
df_top10_EFF
# Out:
#       Rk             Player Pos   G   FG   FGA   FT  FTA  TRB  AST  STL  BLK  \
# 255  213       LeBron James  PF  76  765  1354  403  535  610  551  129   67
# 148  120       Kevin Durant  SF  81  731  1433  679  750  640  374  116  105
# 78    64       Kobe Bryant*  SG  78  738  1595  525  626  433  469  106   25
# 208  170       James Harden  SG  78  585  1337  674  792  379  455  142   38
# 307  257          David Lee  PF  79  602  1160  255  320  886  279   67   22
# 146  118        Tim Duncan*   C  69  490   976  245  300  686  184   50  183
# 409  334         Chris Paul  PG  70  412   856  286  323  262  678  169   10
# 240  198         Al Horford   C  74  576  1060  134  208  757  240   78   78
# 22    16    Carmelo Anthony  PF  67  669  1489  425  512  460  171   52   32
# 7      6  LaMarcus Aldridge  PF  74  638  1318  282  348  670  192   62   91
#
#      TOV   PTS  Player Efficiency Rating
# 255  226  2036                 32.184211
# ...

# %%
df_top10_EFF.describe()
# Out:
#                Rk        Age          G         GS           MP          FG  \
# count   10.000000  10.000000  10.000000  10.000000    10.000000   10.000000
# mean   149.600000  28.200000  74.600000  74.600000  2734.200000  620.600000
# std    105.403141   4.049691   4.671426   4.671426   332.683634  112.368639
# min      6.000000  23.000000  67.000000  67.000000  2078.000000  412.000000
# 25%     77.500000  26.250000  71.000000  71.000000  2550.500000  578.250000
# 50%    145.000000  27.500000  75.000000  75.000000  2833.500000  620.000000
# 75%    209.250000  28.750000  78.000000  78.000000  2965.500000  715.500000
# max    334.000000  36.000000  81.000000  81.000000  3119.000000  765.000000
#
#                FGA        FG%          3P        3PA  ...         ORB  \
# count    10.000000  10.000000   10.000000   10.00000  ...   10.000000
# mean   1257.800000   0.495400   79.300000  215.80000  ...  117.000000
# std     237.240525   0.040495   72.228111  193.71732  ...   62.494444
# ...
